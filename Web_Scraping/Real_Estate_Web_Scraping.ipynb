# %%
import pandas as pd 
import numpy as np
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Website = magicbrics

# %%
URl='https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page=1&category=S'

# %%
page=requests.get(URl)

# %%
# checking the status of url page
page.status_code
# Out:
# 200

# %%
htmlcode=page.text

# %%
htmlcode
# Out:
# '\n<!DOCTYPE html>\n<html>\n<head>\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'dataLayer\',\'GTM-WQW25Z\');</script>\n<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\nnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\nj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n})(window,document,\'script\',\'MB_GTM_dataLayer\',\'GTM-N7Q8HKZ\');</script>\n<title>Properties in Hyderabad</title>\n<meta name="description" content="flats available for Sale in Hyderabad Buy Ready to Move in & Resale Multistorey Apartments in Hyderabad ">\n<meta name
# ...

# %%
soup=BeautifulSoup(htmlcode)

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html>
# <head>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-WQW25Z');</script>
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','MB_GTM_dataLayer','GTM-N7Q8HKZ');</script>
# <title>Properties in Hyderabad</title>
# <meta content="flats available for Sale in Hyderabad Buy Ready to Move in &amp; Resale Multistorey Apartments in Hyderabad " name="description"/>
# ...

# %% [markdown]
# ## Taking tag and class from the website

# %% [markdown]
# #### company --> tag = 'p'  class = "proHeading"
#
# #### price ---> tag = "div"  class = "proPriceField"
#
# #### rating ---> tag = "div" class = "ratedstars"
#
# #### location ---> tag = "p"  class = "proGroup"
#
# #### published_by---> tag = "p" class = "proGroup projDeveloper"
#
# #### bedroom---> tag = "div" class = "proDescColm1"
#
# #### Floors---> tag = "div" class = "floorPlans"
#
# #### Construction_status---> tag = "div" class = "proDetailsRowElm posByCons"
#
# #### Area---> tag = "div" class = "proDescColm2"

# %% [markdown]
# # find

# %%
company=soup.find('p',attrs={"class":"proHeading"})

# %%
company.text
# Out:
# '\nEmpire Meadows\n'

# %%
price=soup.find("div",attrs={"class":"proPriceField"})

# %%
price.text
# Out:
# '63.7 Lac - 80.3 Lac'

# %%
rating=soup.find("div",attrs={"class":"ratedstars"})

# %%
rating.text
# Out:
# '\n\n'

# %% [markdown]
# # Find_all

# %%
soup.find_all("p",attrs={"class":"proGroup"})
# Out:
# [<p class="proGroup">
#  in <a href="https://www.magicbricks.com/Miyapur-in-Hyderabad-Overview#" target="_blank">Miyapur, NH 9</a>
#  , <a href="https://www.magicbricks.com/Miyapur-in-Hyderabad-Overview#" target="_blank">Hyderabad</a>
#  </p>,
#  <p class="proGroup projDeveloper">
#  <label>by</label> <span>Empire Meadows Pvt. Ltd.</span>
#  </p>,
#  <p class="proGroup">
#  in <a href="https://www.magicbricks.com/Kondapur-in-Hyderabad-Overview#" target="_blank">Kondapur</a>
#  , <a href="https://www.magicbricks.com/Kondapur-in-Hyderabad-Overview#" target="_blank">Hyderabad</a>
#  </p>,
#  <p class="proGroup projDeveloper">
#  <label>by</label> <span>SMR Holdings</span>
#  </p>,
#  <p class="proGroup">
#  in <a href="https://www.magicbricks.com/Kismatpur-in-Hyderabad-Overview#" target="_blank">Kismatpur, Outer Ring Road</a>
#  , <a href="https://www.magicbricks.com/Kismatpur-in-Hyderabad-Overview#" target="_blank">Hyderabad</a>
#  </p>,
#  <p class="proGroup projDeveloper">
# ...

# %%
soup.find_all("div",attrs={"class":"proDescColm1"})
# Out:
# [<div class="proDescColm1">
#  2 BHK
#  Flat
#  <input id="propertyType798403" type="hidden" value="Flat"/>
#  <input id="contactType97885" type="hidden" value="Project"/>
#  <input id="propertyTypeCode798403" type="hidden" value="10002"/>
#  </div>,
#  <div class="proDescColm1">
#  3 BHK
#  Flat
#  <input id="propertyType51442" type="hidden" value="Flat"/>
#  <input id="contactType97885" type="hidden" value="Project"/>
#  <input id="propertyTypeCode51442" type="hidden" value="10002"/>
#  </div>,
#  <div class="proDescColm1">
#  2 BHK
#  Flat
#  <input id="propertyType439525" type="hidden" value="Flat"/>
#  <input id="contactType93372" type="hidden" value="Project"/>
#  <input id="propertyTypeCode439525" type="hidden" value="10002"/>
#  </div>,
#  <div class="proDescColm1">
#  3 BHK
#  Flat
#  <input id="propertyType764657" type="hidden" value="Flat"/>
#  <input id="contactType93372" type="hidden" value="Project"/>
#  <input id="propertyTypeCode764657" type="hidden" value="10002"/>
# ...

# %%
soup.find_all("div",attrs={"class":"floorPlans"})
# Out:
# [<div class="floorPlans" onclick="trackProjEvent('Photo_click', 'Floor_Plan'); showPhotoMap('https://www.magicbricks.com/bricks/photoComponent.html?prjPsmId=5022442&amp;fromPage=search&amp;imageId=','5022442_C');"><span></span>8 Floor Plan</div>,
#  <div class="floorPlans" onclick="trackProjEvent('Photo_click', 'Floor_Plan'); showPhotoMap('https://www.magicbricks.com/bricks/photoComponent.html?prjPsmId=5080397&amp;fromPage=search&amp;imageId=','5080397_C');"><span></span>19 Floor Plan</div>,
#  <div class="floorPlans" onclick="trackProjEvent('Photo_click', 'Floor_Plan'); showPhotoMap('https://www.magicbricks.com/bricks/photoComponent.html?prjPsmId=5110369&amp;fromPage=search&amp;imageId=','5110369_C');"><span></span>2 Floor Plan</div>,
#  <div class="floorPlans" onclick="trackProjEvent('Photo_click', 'Floor_Plan'); showPhotoMap('https://www.magicbricks.com/bricks/photoComponent.html?prjPsmId=5097685&amp;fromPage=search&amp;imageId=','5097685_C');"><span></span>13 Floor Plan</div>,
# ...

# %% [markdown]
# ### Generating pages for the URL

# %%
# Generating the url to all the required pages.
for i in range(1,45):
    print('https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page={}&category=S'.format(i))
# Out:
# https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page=1&category=S
# https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page=2&category=S
# https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page=3&category=S
# https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page=4&category=S
# ...

# %%
# Taking all the information from the website and appending into the below mentioned lsts.
company = []
price = []
rating = []
location = []
published = []
floor = []
bedroom = []
construction = []
Area = []


for i in range(1,45):
    URL = 'https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page={}&category=S'.format(i)
    
    page = requests.get(URL)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    # title
    companies = soup.find_all("p",attrs={"class":"proHeading"})
    for item in companies:
        company.append(item.text)
        
    # models
    ratings = soup.find_all("div",attrs={"class":"ratedstars"})
    for item in ratings:
        rating.append(item.text)
        
    # prices
    prices = soup.find_all("div",attrs={"class":"proPriceField"})
    for item in prices:
        price.append(item.text)
        
    # features
    locations = soup.find_all("p",attrs={"class":"proGroup"})
    for item in locations:
        location.append(item.text)
        
    published_by = soup.find_all("p",attrs={"class":"proGroup projDeveloper"})
    for item in published_by:
        published.append(item.text)
        
    floors = soup.find_all("div",attrs={"class":"floorPlans"})
    for item in floors:
        floor.append(item.text)
        
    bedrooms = soup.find_all("div",attrs={"class":"proDescColm1"})
    for item in bedrooms:
        bedroom.append(item.text)
        
    construction_status = soup.find_all("div",attrs={"class":"proDetailsRowElm posByCons"})
    for item in construction_status:                                               
        construction.append(item.text)
        
    Area_sq_ft = soup.find_all("div",attrs={"class":"proDescColm2"})
    for item in Area_sq_ft:
        Area.append(item.text)

# %%
print(len(company))
print(len(price)) 
print(len(rating))
print(len(location))
print(len(published))
print(len(floor)) 
print(len(bedroom))
print(len(construction))
print(len(Area))
# Out:
# 439
# 434
# 279
# 856
# 417
# 362
# 640
# 439
# 640

# %%
company = []
price = []
rating = []
location = []
published = []
floor = []
bedroom = []
construction = []
Area = []


for i in range(1,45):
    URL = 'https://www.magicbricks.com/Real-estate-projects-Search/residential-new-project?&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment,Residential-House,Villa&cityName=Hyderabad&mbTrackSrc=tabChange&page={}&category=S'.format(i)
    
    page = requests.get(URL)
    htmlCode = page.text
    
    soup = BeautifulSoup(htmlCode)
    
    for x in soup.find_all("div", attrs={"class":"srpBlockListRow"}):
    
        # title
        companies = x.find("p",attrs={"class":"proHeading"})
        if companies is None:
            company.append(np.NaN)
        else:
            company.append(companies.text)
        
        # models
        ratings = x.find("div",attrs={"class":"ratedstars"})
        if ratings is None:
            rating.append(np.NaN)
        else:
            rating.append(ratings.text)
        
        # prices
        prices = x.find("div",attrs={"class":"proPriceField"})
        if prices is None:
            price.append(np.NaN)
        else:
            price.append(prices.text)
        
        # features
        locations = x.find("p",attrs={"class":"proGroup"})
        if locations is None:
            location.append(np.NaN)
        else:
            location.append(locations.text)
        
        published_by = x.find("p",attrs={"class":"proGroup projDeveloper"})
        if published_by is None:
            published.append(np.NaN)
        else:
            published.append(published_by.text)
        
        floors = x.find("div",attrs={"class":"floorPlans"})
        if floors is None:
            floor.append(np.NaN)
        else:
            floor.append(floors.text)
        
        bedrooms = x.find("div",attrs={"class":"proDescColm1"})
        if bedrooms is None:
            bedroom.append(np.NaN)
        else:
            bedroom.append(bedrooms.text)
        
        construction_status = x.find("div",attrs={"class":"proDetailsRowElm posByCons"})
        if construction_status is None:
            construction.append(np.NaN)
        else:
            construction.append(construction_status.text)
        
        Area_sq_ft = x.find("div",attrs={"class":"proDescColm2"})
        if Area_sq_ft is None:
            Area.append(np.NaN)                          
        else:
            Area.append(Area_sq_ft.text)

# %%
print(len(company))
print(len(price)) 
print(len(rating))
print(len(location))
print(len(published))
print(len(floor)) 
print(len(bedroom))
print(len(construction))
print(len(Area))
# Out:
# 439
# 439
# 439
# 439
# 439
# 439
# 439
# 439
# 439

# %% [markdown]
# # Creating a DataFrame and saving it in a csv file

# %%
df = pd.DataFrame({"companies":company, "prices":price, "ratings":rating, "locations":location, "published_by":published, "floors":floor, "bedrooms":bedroom, "construction_status":construction, "Area_sq_ft":Area})

# %%
df
# Out:
#                           companies               prices ratings  \
# 0                \nEmpire Meadows\n  63.7 Lac - 80.3 Lac    \n\n
# 1              \nSMR Vinay Iconia\n    1.10 Cr - 1.89 Cr     NaN
# 2                \nTriumph Villas\n    3.26 Cr - 3.66 Cr     NaN
# 3         \nShree Rath Apartments\n   52.5 Lac - 1.08 Cr     NaN
# 4                  \nAakriti Miro\n   88.3 Lac - 1.24 Cr     NaN
# ..                              ...                  ...     ...
# 434             \nSri Sri Gokulam\n       84 Lac Onwards     NaN
# 435              \nAditya Windsor\n      1.85 Cr Onwards     NaN
# 436  \nProject Hill Ridge Springs\n      1.70 Cr Onwards     NaN
# 437           \nNSK Bliss Meadows\n      72 Lac - 76 Lac     NaN
# 438     \nFresh Living Apartments\n      1.60 Cr Onwards    \n\n
#
#                                             locations  \
# 0                   \nin Miyapur, NH 9\n, Hyderabad\n
# 1                        \nin Kondapur\n, Hyderabad\n
# ...

# %%
df.shape
# Out:
# (439, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   companies            439 non-null    object
#  1   prices               434 non-null    object
#  2   ratings              31 non-null     object
#  3   locations            439 non-null    object
#  4   published_by         417 non-null    object
#  5   floors               362 non-null    object
#  6   bedrooms             439 non-null    object
#  7   construction_status  439 non-null    object
#  8   Area_sq_ft           439 non-null    object
# dtypes: object(9)
# memory usage: 31.0+ KB

# %% [markdown]
# # replacing '\n' from the columns with ''

# %%
# replacing '\n' with '' and assigning in to column
df['companies']=df['companies'].apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['companies']
# Out:
# 0                  Empire Meadows
# 1                SMR Vinay Iconia
# 2                  Triumph Villas
# 3           Shree Rath Apartments
# 4                    Aakriti Miro
#                   ...
# 434               Sri Sri Gokulam
# 435                Aditya Windsor
# 436    Project Hill Ridge Springs
# 437             NSK Bliss Meadows
# 438       Fresh Living Apartments
# Name: companies, Length: 439, dtype: object

# %%
df['locations']=df['locations'].apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['locations'].head()
# Out:
# 0                   in Miyapur, NH 9, Hyderabad
# 1                        in Kondapur, Hyderabad
# 2      in Kismatpur, Outer Ring Road, Hyderabad
# 3                        in Nizampet, Hyderabad
# 4    in Nallagandla, Serilingampally, Hyderabad
# Name: locations, dtype: object

# %%
df['published_by']=df['published_by'].fillna(0).astype("string").apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['published_by'].head()
# Out:
# 0       by Empire Meadows Pvt. Ltd.
# 1                   by SMR Holdings
# 2    by Vaishnavi Estates Pvt. Ltd.
# 3              by Unnati Build Tech
# 4                by Aakriti Housing
# Name: published_by, dtype: object

# %%
df['bedrooms']=df['bedrooms'].apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['bedrooms'].head()
# Out:
# 0     2 BHKFlat
# 1     2 BHKFlat
# 2    3 BHKVilla
# 3     2 BHKFlat
# 4     2 BHKFlat
# Name: bedrooms, dtype: object

# %%
df['construction_status']=df['construction_status'].apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['construction_status'].head()
# Out:
# 0    Under Construction
# 1    Possession in 2022
# 2    Under Construction
# 3    Possession in 2025
# 4    Under Construction
# Name: construction_status, dtype: object

# %%
df['Area_sq_ft']=df['Area_sq_ft'].apply(lambda x: x.replace('\n','') if '\n' in x else x)

# %%
df['Area_sq_ft']
# Out:
# 0                   1245 - 1250 sqft
# 1                   1360 - 1535 sqft
# 2                   3264 - 3661 sqft
# 3                    955 - 1025 sqft
# 4                   1318 - 1400 sqft
#                    ...
# 434                        1370 sqft
# 435           2692 sqft(Carpet Area)
# 436                        2560 sqft
# 437    1145 - 1150 sqft(Carpet Area)
# 438                        2059 sqft
# Name: Area_sq_ft, Length: 439, dtype: object

# %%
df
# Out:
#                       companies               prices ratings  \
# 0                Empire Meadows  63.7 Lac - 80.3 Lac    \n\n
# 1              SMR Vinay Iconia    1.10 Cr - 1.89 Cr     NaN
# 2                Triumph Villas    3.26 Cr - 3.66 Cr     NaN
# 3         Shree Rath Apartments   52.5 Lac - 1.08 Cr     NaN
# 4                  Aakriti Miro   88.3 Lac - 1.24 Cr     NaN
# ..                          ...                  ...     ...
# 434             Sri Sri Gokulam       84 Lac Onwards     NaN
# 435              Aditya Windsor      1.85 Cr Onwards     NaN
# 436  Project Hill Ridge Springs      1.70 Cr Onwards     NaN
# 437           NSK Bliss Meadows      72 Lac - 76 Lac     NaN
# 438     Fresh Living Apartments      1.60 Cr Onwards    \n\n
#
#                                       locations  \
# 0                   in Miyapur, NH 9, Hyderabad
# 1                        in Kondapur, Hyderabad
# 2      in Kismatpur, Outer Ring Road, Hyderabad
# ...

# %%
df['prices']
# Out:
# 0      63.7 Lac - 80.3 Lac
# 1        1.10 Cr - 1.89 Cr
# 2        3.26 Cr - 3.66 Cr
# 3       52.5 Lac - 1.08 Cr
# 4       88.3 Lac - 1.24 Cr
#               ...
# 434         84 Lac Onwards
# 435        1.85 Cr Onwards
# 436        1.70 Cr Onwards
# 437        72 Lac - 76 Lac
# 438        1.60 Cr Onwards
# Name: prices, Length: 439, dtype: object

# %% [markdown]
# # Regular expression

# %%
import re

# %%
reg = r'^[\d]+[\s.\d]+[a-zA-z]+'
df['start_price']=df['prices'].apply(lambda x: re.findall(reg,str(x)))

# %%
df['start_price']
# Out:
# 0      [63.7 Lac]
# 1       [1.10 Cr]
# 2       [3.26 Cr]
# 3      [52.5 Lac]
# 4      [88.3 Lac]
#           ...
# 434      [84 Lac]
# 435     [1.85 Cr]
# 436     [1.70 Cr]
# 437      [72 Lac]
# 438     [1.60 Cr]
# Name: start_price, Length: 439, dtype: object

# %%
reg= r'[-][\s]+[\d.\s]+[a-zA-Z]+'
df['final_price']=df['prices'].apply(lambda x: re.findall(reg,str(x)))

# %%
df['final_price']
# Out:
# 0      [- 80.3 Lac]
# 1       [- 1.89 Cr]
# 2       [- 3.66 Cr]
# 3       [- 1.08 Cr]
# 4       [- 1.24 Cr]
#            ...
# 434              []
# 435              []
# 436              []
# 437      [- 76 Lac]
# 438              []
# Name: final_price, Length: 439, dtype: object

# %%
df
# Out:
#                       companies               prices ratings  \
# 0                Empire Meadows  63.7 Lac - 80.3 Lac    \n\n
# 1              SMR Vinay Iconia    1.10 Cr - 1.89 Cr     NaN
# 2                Triumph Villas    3.26 Cr - 3.66 Cr     NaN
# 3         Shree Rath Apartments   52.5 Lac - 1.08 Cr     NaN
# 4                  Aakriti Miro   88.3 Lac - 1.24 Cr     NaN
# ..                          ...                  ...     ...
# 434             Sri Sri Gokulam       84 Lac Onwards     NaN
# 435              Aditya Windsor      1.85 Cr Onwards     NaN
# 436  Project Hill Ridge Springs      1.70 Cr Onwards     NaN
# 437           NSK Bliss Meadows      72 Lac - 76 Lac     NaN
# 438     Fresh Living Apartments      1.60 Cr Onwards    \n\n
#
#                                       locations  \
# 0                   in Miyapur, NH 9, Hyderabad
# 1                        in Kondapur, Hyderabad
# 2      in Kismatpur, Outer Ring Road, Hyderabad
# ...

# %%
df['locations']
# Out:
# 0                     in Miyapur, NH 9, Hyderabad
# 1                          in Kondapur, Hyderabad
# 2        in Kismatpur, Outer Ring Road, Hyderabad
# 3                          in Nizampet, Hyderabad
# 4      in Nallagandla, Serilingampally, Hyderabad
#                           ...
# 434                        in Kondapur, Hyderabad
# 435                        in Kondapur, Hyderabad
# 436                      in Gachibowli, Hyderabad
# 437     in Madinaguda, Hafeezpet, NH 9, Hyderabad
# 438                        in Madhapur, Hyderabad
# Name: locations, Length: 439, dtype: object

# %%
regex=r'^[a-z]+\s[a-zA-z\s]+'
df['locality']=df['locations'].apply(lambda x: re.findall(regex,str(x)))

# %%
df['locality']
# Out:
# 0          [in Miyapur]
# 1         [in Kondapur]
# 2        [in Kismatpur]
# 3         [in Nizampet]
# 4      [in Nallagandla]
#              ...
# 434       [in Kondapur]
# 435       [in Kondapur]
# 436     [in Gachibowli]
# 437     [in Madinaguda]
# 438       [in Madhapur]
# Name: locality, Length: 439, dtype: object

# %%
df['ratings'].isnull().value_counts()
# Out:
# True     408
# False     31
# Name: ratings, dtype: int64

# %%
regex=r'^[\d]+'
df['floor_plan']=df['floors'].apply(lambda x: re.findall(regex,str(x)))

# %%
df['floor_plan']
# Out:
# 0       [8]
# 1      [19]
# 2       [2]
# 3      [13]
# 4      [19]
#        ...
# 434    [17]
# 435    [10]
# 436     [4]
# 437    [17]
# 438    [36]
# Name: floor_plan, Length: 439, dtype: object

# %%
df['floor_plan'].isnull().value_counts()
# Out:
# False    439
# Name: floor_plan, dtype: int64

# %%
df['bedrooms'].isnull().value_counts()
# Out:
# False    439
# Name: bedrooms, dtype: int64

# %%
df['locations'].isnull().value_counts()
# Out:
# False    439
# Name: locations, dtype: int64

# %%
df
# Out:
#                       companies               prices ratings  \
# 0                Empire Meadows  63.7 Lac - 80.3 Lac    \n\n
# 1              SMR Vinay Iconia    1.10 Cr - 1.89 Cr     NaN
# 2                Triumph Villas    3.26 Cr - 3.66 Cr     NaN
# 3         Shree Rath Apartments   52.5 Lac - 1.08 Cr     NaN
# 4                  Aakriti Miro   88.3 Lac - 1.24 Cr     NaN
# ..                          ...                  ...     ...
# 434             Sri Sri Gokulam       84 Lac Onwards     NaN
# 435              Aditya Windsor      1.85 Cr Onwards     NaN
# 436  Project Hill Ridge Springs      1.70 Cr Onwards     NaN
# 437           NSK Bliss Meadows      72 Lac - 76 Lac     NaN
# 438     Fresh Living Apartments      1.60 Cr Onwards    \n\n
#
#                                       locations  \
# 0                   in Miyapur, NH 9, Hyderabad
# 1                        in Kondapur, Hyderabad
# 2      in Kismatpur, Outer Ring Road, Hyderabad
# ...

# %% [markdown]
# # Data manupulation

# %%
df['start_price'] = df['start_price'].apply(lambda x : ''.join(x))

# %%
df['start_price']=df['start_price'].apply(lambda x: float(x.replace('Lac',''))*100000 if 'Lac' in x else float(x.replace('Cr',''))*10000000 if "Cr" in x else float(x.replace('','0')))

# %%
df['start_price']
# Out:
# 0       6370000.0
# 1      11000000.0
# 2      32600000.0
# 3       5250000.0
# 4       8830000.0
#           ...
# 434     8400000.0
# 435    18500000.0
# 436    17000000.0
# 437     7200000.0
# 438    16000000.0
# Name: start_price, Length: 439, dtype: float64

# %%
df['final_price']
# Out:
# 0      [- 80.3 Lac]
# 1       [- 1.89 Cr]
# 2       [- 3.66 Cr]
# 3       [- 1.08 Cr]
# 4       [- 1.24 Cr]
#            ...
# 434              []
# 435              []
# 436              []
# 437      [- 76 Lac]
# 438              []
# Name: final_price, Length: 439, dtype: object

# %%
df['final_price'] = df['final_price'].apply(lambda x : ''.join(x))

# %%
df['final_price']=df['final_price'].fillna(np.nan).astype(str).apply(lambda x: float(x.replace('Lac','').replace('-',''))*100000 if 'Lac' in x else float(x.replace('Cr','').replace('-',''))*10000000 if 'Cr' in x else x.replace('','0'))

# %%
df['final_price']=df['final_price'].astype(object).astype(float)

# %%
df['final_price']
# Out:
# 0       8030000.0
# 1      18900000.0
# 2      36600000.0
# 3      10800000.0
# 4      12400000.0
#           ...
# 434           0.0
# 435           0.0
# 436           0.0
# 437     7600000.0
# 438           0.0
# Name: final_price, Length: 439, dtype: float64

# %%
df['locality'] = df['locality'].apply(lambda x : ''.join(x))

# %%
df['locality']=df['locality'].apply(lambda x: x.replace('in','') if 'in' in x else x)

# %%
df['locality']
# Out:
# 0           Miyapur
# 1          Kondapur
# 2         Kismatpur
# 3          Nizampet
# 4       Nallagandla
#            ...
# 434        Kondapur
# 435        Kondapur
# 436      Gachibowli
# 437        Madaguda
# 438        Madhapur
# Name: locality, Length: 439, dtype: object

# %%
df['bedrooms'] = df['bedrooms'].apply(lambda x : ''.join(x))

# %%
df['bedrooms']
# Out:
# 0       2 BHKFlat
# 1       2 BHKFlat
# 2      3 BHKVilla
# 3       2 BHKFlat
# 4       2 BHKFlat
#           ...
# 434     2 BHKFlat
# 435     4 BHKFlat
# 436     4 BHKFlat
# 437     2 BHKFlat
# 438     3 BHKFlat
# Name: bedrooms, Length: 439, dtype: object

# %%
#df['Bedrooms']=df['Bedrooms'].replace('',np.nan)

# %%
#df['Bedrooms']=df['Bedrooms'].fillna(0).astype(object).astype('int64')
#df['Bedrooms']

# %%
df['floor_plan'] = df['floor_plan'].apply(lambda x : ''.join(x))

# %%
df['floor_plan']
# Out:
# 0       8
# 1      19
# 2       2
# 3      13
# 4      19
#        ..
# 434    17
# 435    10
# 436     4
# 437    17
# 438    36
# Name: floor_plan, Length: 439, dtype: object

# %%
df['published_by']=df['published_by'].apply(lambda x: x.replace('by','') if 'by' in x else x)

# %%
df['published_by']
# Out:
# 0                          Empire Meadows Pvt. Ltd.
# 1                                      SMR Holdings
# 2                       Vaishnavi Estates Pvt. Ltd.
# 3                                 Unnati Build Tech
# 4                                   Aakriti Housing
#                            ...
# 434                         Abhi Teja Constructions
# 435     Aditya Construction Company India Pvt. Ltd.
# 436                 IVR Prime Urban Developers Ltd.
# 437                      Nsk Constructions Builders
# 438                     Vaishnavi Estates Pvt. Ltd.
# Name: published_by, Length: 439, dtype: object

# %%
df['Area_sq_ft'] = df['Area_sq_ft'].apply(lambda x : ''.join(x))

# %%
df
# Out:
#                       companies               prices ratings  \
# 0                Empire Meadows  63.7 Lac - 80.3 Lac    \n\n
# 1              SMR Vinay Iconia    1.10 Cr - 1.89 Cr     NaN
# 2                Triumph Villas    3.26 Cr - 3.66 Cr     NaN
# 3         Shree Rath Apartments   52.5 Lac - 1.08 Cr     NaN
# 4                  Aakriti Miro   88.3 Lac - 1.24 Cr     NaN
# ..                          ...                  ...     ...
# 434             Sri Sri Gokulam       84 Lac Onwards     NaN
# 435              Aditya Windsor      1.85 Cr Onwards     NaN
# 436  Project Hill Ridge Springs      1.70 Cr Onwards     NaN
# 437           NSK Bliss Meadows      72 Lac - 76 Lac     NaN
# 438     Fresh Living Apartments      1.60 Cr Onwards    \n\n
#
#                                       locations  \
# 0                   in Miyapur, NH 9, Hyderabad
# 1                        in Kondapur, Hyderabad
# 2      in Kismatpur, Outer Ring Road, Hyderabad
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   companies            439 non-null    object
#  1   prices               434 non-null    object
#  2   ratings              31 non-null     object
#  3   locations            439 non-null    object
#  4   published_by         439 non-null    object
#  5   floors               362 non-null    object
#  6   bedrooms             439 non-null    object
#  7   construction_status  439 non-null    object
#  8   Area_sq_ft           439 non-null    object
#  9   start_price          439 non-null    float64
#  10  final_price          439 non-null    float64
#  11  locality             439 non-null    object
#  12  floor_plan           439 non-null    object
# dtypes: float64(2), object(11)
# memory usage: 44.7+ KB

# %%
df['floor_plan']=df['floor_plan'].replace('',np.nan)
df['floor_plan']
# Out:
# 0       8
# 1      19
# 2       2
# 3      13
# 4      19
#        ..
# 434    17
# 435    10
# 436     4
# 437    17
# 438    36
# Name: floor_plan, Length: 439, dtype: object

# %%
df['floor_plan']=df['floor_plan'].fillna(0).astype(object).astype('int64')

# %%
df['floor_plan']
# Out:
# 0       8
# 1      19
# 2       2
# 3      13
# 4      19
#        ..
# 434    17
# 435    10
# 436     4
# 437    17
# 438    36
# Name: floor_plan, Length: 439, dtype: int64

# %%
df['floor_plan'].isnull().value_counts()
# Out:
# False    439
# Name: floor_plan, dtype: int64

# %%
df['bedrooms'].isnull().value_counts()
# Out:
# False    439
# Name: bedrooms, dtype: int64

# %%
df['start_price'].isnull().value_counts()
# Out:
# False    439
# Name: start_price, dtype: int64

# %%
df['final_price'].isnull().value_counts()
# Out:
# False    439
# Name: final_price, dtype: int64

# %% [markdown]
# # Droping the columns

# %%
df['ratings'].isnull().value_counts()
# Out:
# True     408
# False     31
# Name: ratings, dtype: int64

# %%
df.drop('ratings', inplace=True,axis=1)

# %%
df.drop('prices', inplace=True, axis=1)
df.drop('floors', inplace=True, axis=1)
#df.drop('bedrooms',inplace=True, axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   companies            439 non-null    object
#  1   locations            439 non-null    object
#  2   published_by         439 non-null    object
#  3   bedrooms             439 non-null    object
#  4   construction_status  439 non-null    object
#  5   Area_sq_ft           439 non-null    object
#  6   start_price          439 non-null    float64
#  7   final_price          439 non-null    float64
#  8   locality             439 non-null    object
#  9   floor_plan           439 non-null    int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 34.4+ KB

# %%
df
# Out:
#                       companies                                   locations  \
# 0                Empire Meadows                 in Miyapur, NH 9, Hyderabad
# 1              SMR Vinay Iconia                      in Kondapur, Hyderabad
# 2                Triumph Villas    in Kismatpur, Outer Ring Road, Hyderabad
# 3         Shree Rath Apartments                      in Nizampet, Hyderabad
# 4                  Aakriti Miro  in Nallagandla, Serilingampally, Hyderabad
# ..                          ...                                         ...
# 434             Sri Sri Gokulam                      in Kondapur, Hyderabad
# 435              Aditya Windsor                      in Kondapur, Hyderabad
# 436  Project Hill Ridge Springs                    in Gachibowli, Hyderabad
# 437           NSK Bliss Meadows   in Madinaguda, Hafeezpet, NH 9, Hyderabad
# 438     Fresh Living Apartments                      in Madhapur, Hyderabad
#
# ...

# %%
df.isnull().sum()
# Out:
# companies              0
# locations              0
# published_by           0
# bedrooms               0
# construction_status    0
# Area_sq_ft             0
# start_price            0
# final_price            0
# locality               0
# floor_plan             0
# dtype: int64

# %%
df.describe()
# Out:
#         start_price   final_price  floor_plan
# count  4.390000e+02  4.390000e+02  439.000000
# mean   1.119613e+07  1.327289e+07    7.974943
# std    1.274149e+07  3.399705e+07    8.454920
# min    0.000000e+00  0.000000e+00    0.000000
# 25%    5.500000e+06  0.000000e+00    2.000000
# 50%    7.800000e+06  8.740000e+06    5.000000
# 75%    1.160000e+07  1.450000e+07   11.000000
# max    1.400000e+08  6.000000e+08   65.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 439 entries, 0 to 438
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   companies            439 non-null    object
#  1   locations            439 non-null    object
#  2   published_by         439 non-null    object
#  3   bedrooms             439 non-null    object
#  4   construction_status  439 non-null    object
#  5   Area_sq_ft           439 non-null    object
#  6   start_price          439 non-null    float64
#  7   final_price          439 non-null    float64
#  8   locality             439 non-null    object
#  9   floor_plan           439 non-null    int64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 34.4+ KB

# %% [markdown]
# # Data Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df
# Out:
#                       companies                                   locations  \
# 0                Empire Meadows                 in Miyapur, NH 9, Hyderabad
# 1              SMR Vinay Iconia                      in Kondapur, Hyderabad
# 2                Triumph Villas    in Kismatpur, Outer Ring Road, Hyderabad
# 3         Shree Rath Apartments                      in Nizampet, Hyderabad
# 4                  Aakriti Miro  in Nallagandla, Serilingampally, Hyderabad
# ..                          ...                                         ...
# 434             Sri Sri Gokulam                      in Kondapur, Hyderabad
# 435              Aditya Windsor                      in Kondapur, Hyderabad
# 436  Project Hill Ridge Springs                    in Gachibowli, Hyderabad
# 437           NSK Bliss Meadows   in Madinaguda, Hafeezpet, NH 9, Hyderabad
# 438     Fresh Living Apartments                      in Madhapur, Hyderabad
#
# ...

# %%
sns.displot(data=df['start_price'],kind='hist',bins=40)

# %% [markdown]
# From the above histogram plot most of the flats start price is

# %%
sns.displot(df['start_price'],kind='kde')

# %%
sns.displot(df['final_price'],kind='kde')

# %%
plt.figure(figsize=(25,10))
sns.boxplot(data=df, y=df['final_price'],x=df['companies'])
# Out:
# <AxesSubplot:xlabel='companies', ylabel='final_price'>

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, y='start_price', x='floor_plan')
# Out:
# <AxesSubplot:xlabel='floor_plan', ylabel='start_price'>

# %%
sns.jointplot(data=df, x='final_price', y='start_price', kind='scatter')

# %%
plt.figure(figsize=(18,8))
plt.title("Realatioship between locality and start_price")
sns.boxplot(data=df, x='locality',y='start_price')

plt.figure(figsize=(18,8))
plt.title("Realtionship between locality and floor_plan")
sns.boxplot(data=df, x='locality', y='floor_plan')

plt.figure(figsize=(18,6))
plt.title("Relationship between Area_sq_ft and Final")
sns.boxplot(data=df.head(25), x='Area_sq_ft', y='final_price')
# Out:
# <AxesSubplot:title={'center':'Relationship between Area_sq_ft and Final'}, xlabel='Area_sq_ft', ylabel='final_price'>

# %%
plt.figure(figsize=(15,7))
sns.jointplot(data=df, x='floor_plan', y='final_price', kind='scatter')

# %%
sns.jointplot(data=df, x='floor_plan', y='start_price',kind='scatter')

# %% [markdown]
# From the above scatterplot the corelation between the floor_plan and the start_price is having positive nature of corelation

# %%
plt.figure(figsize=(20,8))
sns.boxplot(data=df, x='construction_status', y='start_price')
# Out:
# <AxesSubplot:xlabel='construction_status', ylabel='start_price'>

# %%
sns.pairplot(df)

# %%
sns.heatmap(data=df.describe(include=['number']))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(25,10))
sns.countplot(x=df['locality'])
# Out:
# <AxesSubplot:xlabel='locality', ylabel='count'>

# %% [markdown]
# From the above countplot most of the

# %%
plt.figure(figsize=(15,7))
sns.countplot(x=df['construction_status'])
# Out:
# <AxesSubplot:xlabel='construction_status', ylabel='count'>

# %% [markdown]
# From the above countplot the most of the constructions are ongoing and completes in some years and presently there are more flats are ready to move having the heighest count of flats in the data.

# %%
plt.figure(figsize=(20,10))
df.groupby(['bedrooms'])[['start_price','final_price']].max().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='bedrooms'>

# %% [markdown]
# From the above barplot the starting price for bedrooms is gradually increasing and 3 BHK is having the heighest final price and the starting price for 3 BHK is very less when compared to final price, and also the starting price for 4BHK is greater when compared to 3BHK and final price is less in 4BHK flats.

# %%
plt.figure(figsize=(20,9))
df.groupby(df['locality'])['start_price'].max().plot(kind='bar',color='g')
# Out:
# <AxesSubplot:xlabel='locality'>

# %% [markdown]
# from the above bar plot kondapur is having the heighest starting price for the flats and Gachiboli is second place for the starting heighest price.
